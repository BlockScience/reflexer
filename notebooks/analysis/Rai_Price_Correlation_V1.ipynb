# %% [markdown]
# # Correlation of RAI to Eth price moves - Data as of 3-29-2021
#
# We are performing a vector autogression in order to determine if a casual or multi-casual relationship exists between Eth and Rai price moves. This will help use understand system level price dynamics of the Rai system.
#
# ### Vector Autoregression
#
# Vector autoregression (VAR) is a type of statistical model used to capture the relationship between multiple time series signals as they change over time. VAR models are extensions of univariate autoregression models allowing for multivariate time series analysis.
#
# Autogregressive models use lagged past values of the variable and have an order based on how many times the variable has been lagged, i.e. VAR(2) means two lagged values. Lagged values help to determine if seasonality or reoccuring patterns exist in the data.
#
# A pth-order VAR model is written as:
# $$y_t = c + A_1 y_{t-1} + A_2 y_{t-2} + \cdots + A_p y_{t-p} + e_t,$$
#
# In vector notation, a VAR(1) with 2 variables is:
#
# $$\begin{bmatrix}y_{1,t} \\ y_{2,t}\end{bmatrix} = \begin{bmatrix}c_{1} \\ c_{2}\end{bmatrix} + \begin{bmatrix}a_{1,1}&a_{1,2} \\ a_{2,1}&a_{2,2}\end{bmatrix}\begin{bmatrix}y_{1,t-1} \\ y_{2,t-1}\end{bmatrix} + \begin{bmatrix}e_{1,t} \\ e_{2,t}\end{bmatrix}$$
#
#
# For our VAR model, we will have a vector of prices, $P$ of EthRai(marketPriceEth),RaiUSD(marketPriceUsd), and EthUSD price moves.
#
#
# #### Assumptions:
# * Every error term has a mean of zero and is normally distributed.
# * Variables are stationary. Differenceing can be used to make the data stationary.
# * Data is on the same scale
#
# ### Other methods with fewer assumptions
#
# Non-parametric Bayesian VAR models have been under development and appear to perform well and can operate on nonlinear relationship, heteroscedasticity, and non Gaussian error data[1,2].
#
# Another popular time series analysis modeling technique is the Autorgressive Integrated Moving Average (ARIMA) model. These models are often used in forecasting or when the data shoes evidence of non-stationarity. For multiple time series vectors, like we have here, extensions of the ARIMA model are available, such ARIMAX model that has exogenous variable inputs. ARIMAX models do not have an assumption of Gaussian errors as it uses a maximum likelihood estimation function to fit.
#
# #### References
# - 1 Kalli, Maria & Griffin, Jim E., 2018. "Bayesian nonparametric vector autoregressive models," Journal of Econometrics, Elsevier, vol. 203(2), pages 267-282.
# - 2 Jeliazkov, Ivan. (2013). Nonparametric Vector Autoregressions: Specification, Estimation, and Inference. Advances in Econometrics. 33. 10.1108/S0731-9053(2013)0000031009.
#
#
# We have taken the trade off in assumption for this first version correlation model vs a non-parametric approach for simplicity sake, that current robust python VAR implementations exist, and for illustrative purposes around the concepts we are addressing.

# %%
# import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from math import sqrt

# %% [markdown]
# ## Data
#
# We import the data obtained in the [TheGraphDataSetCreation](TheGraphDataSetCreation.ipynb) notebook and preprocess it.

# %%
graphData = pd.read_csv('saved_results/RaiLiveGraphData.csv')
del graphData['Unnamed: 0']

# %%
graphData.head()
# Out:
#    blockNumber  erc20CoinTotalSupply   globalDebt  \
# 0     11857308           1988.440433  1988.577499
# 1     11860793           2788.440433  2788.617717
# 2     11861040           2788.440433  2788.657935
# 3     11861337           2788.440433  2788.657935
# 4     11861474           3048.440433  3048.645955
#
#                                      redemptionPrice   timestamp  \
# 0  {'block': '11849022', 'id': '0xe313271188492c4...  1613338681
# 1  {'block': '11860755', 'id': '0x40066774f6fb7d3...  1613384616
# 2  {'block': '11861008', 'id': '0x0d551e2a2d55fa8...  1613387890
# 3  {'block': '11861237', 'id': '0x5c67dbb323db039...  1613392101
# 4  {'block': '11861237', 'id': '0x5c67dbb323db039...  1613394096
#
#    hourlyredemptionPriceActual  hourlyredemptionRateActual  \
# 0                         3.14                        3.14
# 1                         3.14                        3.14
# 2                         3.14                        3.14
# 3                         3.14                        3.14
# 4                         3.14                        3.14
#
#    hourlymarketPriceEth  hourlymarketPriceUsd  activeLiquidations  ...  \
# 0              0.002589              4.670500                   0  ...
# 1              0.002481              4.377049                   0  ...
# 2              0.002481              4.406833                   0  ...
# 3              0.002481              4.419266                   0  ...
# 4              0.001769              3.194330                   0  ...
#
#                      globalDebtCeiling systemSurplus  totalActiveSafeCount  \
# 0  115792089237316195423570985008687.9      0.068533                     3
# 1  115792089237316195423570985008687.9      0.108751                     3
# 2  115792089237316195423570985008687.9      0.108751                     3
# 3  115792089237316195423570985008687.9      0.108751                     3
# 4  115792089237316195423570985008687.9      0.116162                     3
#
#                                   wethAddress  RedemptionRateAnnualizedRate  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2                           1.0
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2                           1.0
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2                           1.0
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2                           1.0
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2                           1.0
#
#    RedemptionRateHourlyRate  RedemptionRateEightHourlyRate RedemptionPrice  \
# 0                       1.0                            1.0            3.14
# 1                       1.0                            1.0            3.14
# 2                       1.0                            1.0            3.14
# 3                       1.0                            1.0            3.14
# 4                       1.0                            1.0            3.14
#
#       error error_integral
# 0 -1.530500      -1.530500
# 1 -1.237049      -2.767550
# 2 -1.266833      -4.034383
# 3 -1.279266      -5.313648
# 4 -0.054330      -5.367978
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Exploratory Analysis

# %%
graphData.describe()
# Out:
#         blockNumber  erc20CoinTotalSupply    globalDebt     timestamp  \
# count  9.680000e+02          9.680000e+02  9.680000e+02  9.680000e+02
# mean   1.199348e+07          3.423472e+07  3.465959e+07  1.615150e+09
# std    7.731615e+04          1.358602e+07  1.368873e+07  1.028748e+06
# min    1.185731e+07          1.988440e+03  1.988577e+03  1.613339e+09
# 25%    1.192674e+07          3.212887e+07  3.247190e+07  1.614261e+09
# 50%    1.199251e+07          3.563782e+07  3.650929e+07  1.615136e+09
# 75%    1.205953e+07          4.378923e+07  4.462623e+07  1.616029e+09
# max    1.212903e+07          4.899876e+07  4.918825e+07  1.616953e+09
#
#        hourlyredemptionPriceActual  hourlyredemptionRateActual  \
# count                   968.000000                  968.000000
# mean                      3.060915                    3.060915
# std                       0.047792                    0.047792
# min                       3.013686                    3.013686
# 25%                       3.018242                    3.018242
# 50%                       3.031328                    3.031328
# 75%                       3.108695                    3.108695
# max                       3.140000                    3.140000
#
#        hourlymarketPriceEth  hourlymarketPriceUsd  activeLiquidations  \
# count            968.000000            968.000000          968.000000
# mean               0.001870              3.186711            0.026860
# std                0.000284              0.425674            0.216443
# min                0.001600              2.850455            0.000000
# 25%                0.001675              2.985433            0.000000
# 50%                0.001773              3.098964            0.000000
# 75%                0.002030              3.247577            0.000000
# max                0.004474              8.055382            3.000000
#
#         debtCeiling  ...    Eth_price  debtAvailableToSettle  systemSurplus  \
# count  9.680000e+02  ...   968.000000             968.000000     968.000000
# mean   4.486159e+07  ...  1717.188493          292230.574902  112253.419544
# std    1.559874e+07  ...   148.005290          364865.156104   67166.517314
# min    1.000000e+07  ...  1328.192602               0.000000   -8000.336813
# 25%    3.996953e+07  ...  1598.529399           23588.941750   38636.810709
# 50%    4.686430e+07  ...  1755.372733           45752.103558  146261.966787
# 75%    5.727986e+07  ...  1819.556530          666376.609641  162449.549871
# max    5.727986e+07  ...  2032.578356          943944.359793  178819.337222
#
#        totalActiveSafeCount  RedemptionRateAnnualizedRate  \
# count            968.000000                    968.000000
# mean             811.109504                      0.819082
# std              264.657786                      0.355755
# min                3.000000                      0.168066
# 25%              785.000000                      0.514742
# 50%              849.500000                      0.866781
# 75%             1004.000000                      1.107615
# max             1021.000000                      1.562592
#
#        RedemptionRateHourlyRate  RedemptionRateEightHourlyRate  \
# count                968.000000                     968.000000
# mean                   0.999963                       0.999708
# std                    0.000060                       0.000481
# min                    0.999796                       0.998373
# 25%                    0.999924                       0.999394
# 50%                    0.999984                       0.999869
# 75%                    1.000012                       1.000093
# max                    1.000051                       1.000408
#
#        RedemptionPrice       error  error_integral
# count       968.000000  968.000000      968.000000
# mean          3.060914   -0.125796     -112.290311
# std           0.047790    0.402777       29.020842
# min           3.013686   -4.915382     -137.479740
# 25%           3.018267   -0.161181     -134.382143
# 50%           3.031328   -0.051953     -124.723091
# 75%           3.108695    0.037768      -96.128266
# max           3.140000    0.289543       -1.530500
#
# [8 rows x 23 columns]

# %%
graphData.columns
# Out:
# Index(['blockNumber', 'erc20CoinTotalSupply', 'globalDebt', 'redemptionPrice',
#        'timestamp', 'hourlyredemptionPriceActual',
#        'hourlyredemptionRateActual', 'hourlymarketPriceEth',
#        'hourlymarketPriceUsd', 'activeLiquidations', 'currentFsmUpdate',
#        'currentMedianizerUpdate', 'debtCeiling', 'liquidationsStarted',
#        'totalAnnualizedStabilityFee', 'totalCollateral', 'Eth_price',
#        'coinAddress', 'coinUniswapPair', 'currentCoinMedianizerUpdate',
#        'debtAvailableToSettle', 'globalDebtCeiling', 'systemSurplus',
#        'totalActiveSafeCount', 'wethAddress', 'RedemptionRateAnnualizedRate',
#        'RedemptionRateHourlyRate', 'RedemptionRateEightHourlyRate',
#        'RedemptionPrice', 'error', 'error_integral'],
#       dtype='object')

# %%
graphData.plot(x='blockNumber',y='Eth_price',kind='line',title='EthPrice')

# %%
graphData.plot(x='blockNumber',y='hourlymarketPriceEth',kind='line',title='marketPriceEth')

# %%
graphData.plot(x='blockNumber',y='hourlymarketPriceUsd',kind='line',title='marketPriceUsd')

# %%
graphData.hourlymarketPriceEth.hist()

# %% [markdown]
# Due to the large spikes the market prices during the system initialization, we will cut out the first 100 observations.

# %%
graphData[100:].plot(x='blockNumber',y='hourlymarketPriceEth',kind='line',title='marketPriceUsd')

# %%
# subset data to vector for VAR
P = graphData[100:][['hourlymarketPriceEth','hourlymarketPriceUsd','Eth_price']]

# %%
P.describe()
# Out:
#        hourlymarketPriceEth  hourlymarketPriceUsd    Eth_price
# count            868.000000            868.000000   868.000000
# mean               0.001844              3.111245  1702.971060
# std                0.000205              0.155137   148.443585
# min                0.001600              2.864213  1328.192602
# 25%                0.001671              2.980661  1581.747352
# 50%                0.001758              3.069784  1716.820212
# 75%                0.002030              3.220284  1808.762864
# max                0.002631              3.639484  2032.578356

# %% [markdown]
# ### Data Transformations
#
# We will take the log of the data to reduce the skewness and take the first difference to make the data stationary, meaning that the distribution does not change when shifted by tie.

# %%
## Difference and log values
P['marketPriceEth_log_differenced'] = np.log(P['hourlymarketPriceEth']).diff()
P['marketPriceUsd_log_differenced'] = np.log(P['hourlymarketPriceUsd']).diff()
P['Eth_price_log_differenced'] = np.log(P['Eth_price']).diff()

# %%
P.marketPriceEth_log_differenced.hist()

# %%
P.marketPriceEth_log_differenced.plot()

# %%
P.marketPriceUsd_log_differenced.plot()

# %%
P.Eth_price_log_differenced.plot()

# %%
P.describe()
# Out:
#        hourlymarketPriceEth  hourlymarketPriceUsd    Eth_price  \
# count            868.000000            868.000000   868.000000
# mean               0.001844              3.111245  1702.971060
# std                0.000205              0.155137   148.443585
# min                0.001600              2.864213  1328.192602
# 25%                0.001671              2.980661  1581.747352
# 50%                0.001758              3.069784  1716.820212
# 75%                0.002030              3.220284  1808.762864
# max                0.002631              3.639484  2032.578356
#
#        marketPriceEth_log_differenced  marketPriceUsd_log_differenced  \
# count                      867.000000                      867.000000
# mean                        -0.000037                       -0.000183
# std                          0.009102                        0.011093
# min                         -0.049693                       -0.050115
# 25%                         -0.002318                       -0.004204
# 50%                         -0.000051                        0.000000
# 75%                          0.000835                        0.004136
# max                          0.081117                        0.072969
#
#        Eth_price_log_differenced
# count                 867.000000
# mean                   -0.000144
# std                     0.010949
# min                    -0.059595
# 25%                    -0.002691
# 50%                     0.000000
# 75%                     0.003933
# max                     0.052679

# %% [markdown]
# Standardize the data (rescale values to mean of a 0 and a standard deviation of 1). Standardization will move these different scales/order of magnitude to the same.

# %%
# scaler objects
scalers = []
# features to scale
features = ['marketPriceEth_log_differenced','marketPriceUsd_log_differenced','Eth_price_log_differenced']
for i in features:
    # train the standardization
    scaler = StandardScaler()
    # prepare data for standardization
    values = P[i].values
    values = values.reshape((len(values), 1))
    scaler = scaler.fit(values)
    print('Mean: %f, StandardDeviation: %f' % (scaler.mean_, sqrt(scaler.var_)))
    scalers.append(scaler)
    string = i + '_standardized'
    P[string] = scaler.transform(values)
# Out:
# Mean: -0.000037, StandardDeviation: 0.009097
# Mean: -0.000183, StandardDeviation: 0.011086
# Mean: -0.000144, StandardDeviation: 0.010943

# %% [markdown]
# The following code can be used to inverse the transform
# ```
# inversed = scaler.inverse_transform(normalized)
# ```

# %%
P.describe()
# Out:
#        hourlymarketPriceEth  hourlymarketPriceUsd    Eth_price  \
# count            868.000000            868.000000   868.000000
# mean               0.001844              3.111245  1702.971060
# std                0.000205              0.155137   148.443585
# min                0.001600              2.864213  1328.192602
# 25%                0.001671              2.980661  1581.747352
# 50%                0.001758              3.069784  1716.820212
# 75%                0.002030              3.220284  1808.762864
# max                0.002631              3.639484  2032.578356
#
#        marketPriceEth_log_differenced  marketPriceUsd_log_differenced  \
# count                      867.000000                      867.000000
# mean                        -0.000037                       -0.000183
# std                          0.009102                        0.011093
# min                         -0.049693                       -0.050115
# 25%                         -0.002318                       -0.004204
# 50%                         -0.000051                        0.000000
# 75%                          0.000835                        0.004136
# max                          0.081117                        0.072969
#
#        Eth_price_log_differenced  marketPriceEth_log_differenced_standardized  \
# count                 867.000000                                 8.670000e+02
# mean                   -0.000144                                -1.068946e-17
# std                     0.010949                                 1.000577e+00
# min                    -0.059595                                -5.458815e+00
# 25%                    -0.002691                                -2.507516e-01
# 50%                     0.000000                                -1.565147e-03
# 75%                     0.003933                                 9.584611e-02
# max                     0.052679                                 8.921413e+00
#
#        marketPriceUsd_log_differenced_standardized  \
# count                                 8.670000e+02
# mean                                 -8.707632e-18
# std                                   1.000577e+00
# min                                  -4.503979e+00
# 25%                                  -3.626638e-01
# 50%                                   1.652394e-02
# 75%                                   3.895753e-01
# max                                   6.598478e+00
#
#        Eth_price_log_differenced_standardized
# count                            8.670000e+02
# mean                             3.265362e-17
# std                              1.000577e+00
# min                             -5.432846e+00
# 25%                             -2.327996e-01
# 50%                              1.312597e-02
# 75%                              3.725767e-01
# max                              4.827050e+00

# %%
P.dropna(inplace=True)

# %% [markdown]
# As a final check prior to modeling, we will run the Augmented Dickey-Fuller test to ensure that our data is stationary (non-unit root - A unit root is a stochastic trend in a time series). The test's hypothesis are:
#
#
# * $H_O: \textrm{Time series has a unit root}$
# * $H_A: \textrm{Time series does not have a unit root}$

# %%
for i in features:
    print(i)
    result = adfuller(P[i].values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] > 0.05:
        decision = "fail to reject - unit root present"
    else:
        decision = "reject, no unit root present"
    print(decision)
    print('----------------------------------')
# Out:
# marketPriceEth_log_differenced
# ADF Statistic: -8.770159
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# marketPriceUsd_log_differenced
# ADF Statistic: -10.593379
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# Eth_price_log_differenced
# ADF Statistic: -8.883609
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------

# %% [markdown]
# Based on the Augmented Dickey-Fuller, our preprocessing was successful and none of our univariate time series signals as a unit root. We can now proceed to the VAR model.

# %% [markdown]
# ## Fit model

# %%
# instantiate the var model object from statsmodels
model = VAR(P[['marketPriceEth_log_differenced_standardized',
               'marketPriceUsd_log_differenced_standardized',
               'Eth_price_log_differenced_standardized']])
# Out:
# /home/aclarkdata/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
# calculate the best autocorrelation value
results = model.fit(maxlags=15, ic='aic')

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 28, Mar, 2021
# Time:                     14:47:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                  -0.559981
# Nobs:                     852.000    HQIC:                  -1.03443
# Log likelihood:          -2922.67    FPE:                   0.264837
# AIC:                     -1.32896    Det(Omega_mle):        0.226187
# --------------------------------------------------------------------
# Results for equation marketPriceEth_log_differenced_standardized
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                   0.001681         0.031691            0.053           0.958
# L1.marketPriceEth_log_differenced_standardized          0.179852         0.037747            4.765           0.000
# L1.marketPriceUsd_log_differenced_standardized         -0.171333         0.037192           -4.607           0.000
# L1.Eth_price_log_differenced_standardized              -0.032754         0.054570           -0.600           0.548
# L2.marketPriceEth_log_differenced_standardized         -0.073980         0.043628           -1.696           0.090
# L2.marketPriceUsd_log_differenced_standardized         -0.166533         0.045700           -3.644           0.000
# L2.Eth_price_log_differenced_standardized              -0.088884         0.066736           -1.332           0.183
# L3.marketPriceEth_log_differenced_standardized          0.038739         0.056525            0.685           0.493
# L3.marketPriceUsd_log_differenced_standardized         -0.104109         0.061064           -1.705           0.088
# L3.Eth_price_log_differenced_standardized              -0.022761         0.076509           -0.297           0.766
# L4.marketPriceEth_log_differenced_standardized         -0.058878         0.064185           -0.917           0.359
# L4.marketPriceUsd_log_differenced_standardized         -0.072060         0.070884           -1.017           0.309
# L4.Eth_price_log_differenced_standardized               0.012068         0.084498            0.143           0.886
# L5.marketPriceEth_log_differenced_standardized         -0.043726         0.070100           -0.624           0.533
# L5.marketPriceUsd_log_differenced_standardized         -0.132364         0.078943           -1.677           0.094
# L5.Eth_price_log_differenced_standardized              -0.056899         0.090941           -0.626           0.532
# L6.marketPriceEth_log_differenced_standardized         -0.054768         0.074810           -0.732           0.464
# L6.marketPriceUsd_log_differenced_standardized         -0.059742         0.085067           -0.702           0.482
# L6.Eth_price_log_differenced_standardized              -0.130962         0.094416           -1.387           0.165
# L7.marketPriceEth_log_differenced_standardized          0.020976         0.078820            0.266           0.790
# L7.marketPriceUsd_log_differenced_standardized          0.002092         0.091752            0.023           0.982
# L7.Eth_price_log_differenced_standardized              -0.249023         0.095940           -2.596           0.009
# L8.marketPriceEth_log_differenced_standardized         -0.119408         0.081221           -1.470           0.142
# L8.marketPriceUsd_log_differenced_standardized          0.091654         0.094997            0.965           0.335
# L8.Eth_price_log_differenced_standardized              -0.115027         0.096724           -1.189           0.234
# L9.marketPriceEth_log_differenced_standardized         -0.060316         0.082744           -0.729           0.466
# L9.marketPriceUsd_log_differenced_standardized          0.103604         0.095388            1.086           0.277
# L9.Eth_price_log_differenced_standardized              -0.207934         0.093550           -2.223           0.026
# L10.marketPriceEth_log_differenced_standardized        -0.175203         0.081773           -2.143           0.032
# L10.marketPriceUsd_log_differenced_standardized         0.084324         0.095084            0.887           0.375
# L10.Eth_price_log_differenced_standardized             -0.155943         0.088626           -1.760           0.078
# L11.marketPriceEth_log_differenced_standardized        -0.153629         0.079874           -1.923           0.054
# L11.marketPriceUsd_log_differenced_standardized         0.122808         0.092233            1.332           0.183
# L11.Eth_price_log_differenced_standardized              0.033573         0.083846            0.400           0.689
# L12.marketPriceEth_log_differenced_standardized        -0.020088         0.076133           -0.264           0.792
# L12.marketPriceUsd_log_differenced_standardized        -0.037612         0.087600           -0.429           0.668
# L12.Eth_price_log_differenced_standardized             -0.059074         0.073907           -0.799           0.424
# L13.marketPriceEth_log_differenced_standardized         0.016133         0.069842            0.231           0.817
# L13.marketPriceUsd_log_differenced_standardized        -0.035078         0.080573           -0.435           0.663
# L13.Eth_price_log_differenced_standardized              0.000327         0.061735            0.005           0.996
# L14.marketPriceEth_log_differenced_standardized        -0.061697         0.061463           -1.004           0.315
# L14.marketPriceUsd_log_differenced_standardized        -0.044314         0.070655           -0.627           0.531
# L14.Eth_price_log_differenced_standardized             -0.011637         0.043671           -0.266           0.790
# L15.marketPriceEth_log_differenced_standardized         0.045987         0.052799            0.871           0.384
# L15.marketPriceUsd_log_differenced_standardized        -0.029092         0.055862           -0.521           0.603
# L15.Eth_price_log_differenced_standardized              0.029091         0.034169            0.851           0.395
# ==================================================================================================================
#
# Results for equation marketPriceUsd_log_differenced_standardized
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                  -0.002672         0.031651           -0.084           0.933
# L1.marketPriceEth_log_differenced_standardized          0.082702         0.037700            2.194           0.028
# L1.marketPriceUsd_log_differenced_standardized         -0.213125         0.037145           -5.738           0.000
# L1.Eth_price_log_differenced_standardized              -0.034088         0.054501           -0.625           0.532
# L2.marketPriceEth_log_differenced_standardized         -0.030755         0.043573           -0.706           0.480
# L2.marketPriceUsd_log_differenced_standardized         -0.105521         0.045642           -2.312           0.021
# L2.Eth_price_log_differenced_standardized               0.048962         0.066651            0.735           0.463
# L3.marketPriceEth_log_differenced_standardized          0.096205         0.056454            1.704           0.088
# L3.marketPriceUsd_log_differenced_standardized         -0.108836         0.060986           -1.785           0.074
# L3.Eth_price_log_differenced_standardized               0.091388         0.076412            1.196           0.232
# L4.marketPriceEth_log_differenced_standardized          0.068967         0.064104            1.076           0.282
# L4.marketPriceUsd_log_differenced_standardized         -0.150863         0.070794           -2.131           0.033
# L4.Eth_price_log_differenced_standardized               0.051878         0.084391            0.615           0.539
# L5.marketPriceEth_log_differenced_standardized         -0.020314         0.070011           -0.290           0.772
# L5.marketPriceUsd_log_differenced_standardized         -0.170625         0.078842           -2.164           0.030
# L5.Eth_price_log_differenced_standardized               0.096043         0.090826            1.057           0.290
# L6.marketPriceEth_log_differenced_standardized          0.108219         0.074715            1.448           0.148
# L6.marketPriceUsd_log_differenced_standardized         -0.153092         0.084959           -1.802           0.072
# L6.Eth_price_log_differenced_standardized               0.155663         0.094297            1.651           0.099
# L7.marketPriceEth_log_differenced_standardized          0.096500         0.078720            1.226           0.220
# L7.marketPriceUsd_log_differenced_standardized         -0.127205         0.091635           -1.388           0.165
# L7.Eth_price_log_differenced_standardized               0.095216         0.095818            0.994           0.320
# L8.marketPriceEth_log_differenced_standardized          0.105896         0.081118            1.305           0.192
# L8.marketPriceUsd_log_differenced_standardized         -0.140544         0.094876           -1.481           0.139
# L8.Eth_price_log_differenced_standardized               0.214120         0.096601            2.217           0.027
# L9.marketPriceEth_log_differenced_standardized          0.199801         0.082639            2.418           0.016
# L9.marketPriceUsd_log_differenced_standardized         -0.241851         0.095267           -2.539           0.011
# L9.Eth_price_log_differenced_standardized               0.207508         0.093431            2.221           0.026
# L10.marketPriceEth_log_differenced_standardized         0.229589         0.081669            2.811           0.005
# L10.marketPriceUsd_log_differenced_standardized        -0.327019         0.094964           -3.444           0.001
# L10.Eth_price_log_differenced_standardized              0.231637         0.088514            2.617           0.009
# L11.marketPriceEth_log_differenced_standardized         0.180251         0.079772            2.260           0.024
# L11.marketPriceUsd_log_differenced_standardized        -0.304387         0.092116           -3.304           0.001
# L11.Eth_price_log_differenced_standardized              0.158242         0.083740            1.890           0.059
# L12.marketPriceEth_log_differenced_standardized         0.197143         0.076036            2.593           0.010
# L12.marketPriceUsd_log_differenced_standardized        -0.385387         0.087489           -4.405           0.000
# L12.Eth_price_log_differenced_standardized              0.050289         0.073814            0.681           0.496
# L13.marketPriceEth_log_differenced_standardized         0.043662         0.069754            0.626           0.531
# L13.marketPriceUsd_log_differenced_standardized        -0.055117         0.080471           -0.685           0.493
# L13.Eth_price_log_differenced_standardized             -0.064786         0.061656           -1.051           0.293
# L14.marketPriceEth_log_differenced_standardized        -0.046551         0.061385           -0.758           0.448
# L14.marketPriceUsd_log_differenced_standardized        -0.038278         0.070565           -0.542           0.588
# L14.Eth_price_log_differenced_standardized             -0.144526         0.043615           -3.314           0.001
# L15.marketPriceEth_log_differenced_standardized        -0.129161         0.052732           -2.449           0.014
# L15.marketPriceUsd_log_differenced_standardized         0.166431         0.055791            2.983           0.003
# L15.Eth_price_log_differenced_standardized             -0.050070         0.034126           -1.467           0.142
# ==================================================================================================================
#
# Results for equation Eth_price_log_differenced_standardized
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                  -0.001605         0.020491           -0.078           0.938
# L1.marketPriceEth_log_differenced_standardized         -0.411537         0.024407          -16.861           0.000
# L1.marketPriceUsd_log_differenced_standardized          0.490338         0.024048           20.390           0.000
# L1.Eth_price_log_differenced_standardized              -0.742378         0.035285          -21.040           0.000
# L2.marketPriceEth_log_differenced_standardized         -0.663750         0.028210          -23.529           0.000
# L2.marketPriceUsd_log_differenced_standardized          0.771339         0.029549           26.104           0.000
# L2.Eth_price_log_differenced_standardized              -0.716425         0.043151          -16.603           0.000
# L3.marketPriceEth_log_differenced_standardized         -0.613404         0.036549          -16.783           0.000
# L3.marketPriceUsd_log_differenced_standardized          0.759059         0.039483           19.225           0.000
# L3.Eth_price_log_differenced_standardized              -0.696232         0.049470          -14.074           0.000
# L4.marketPriceEth_log_differenced_standardized         -0.589930         0.041502          -14.215           0.000
# L4.marketPriceUsd_log_differenced_standardized          0.699950         0.045833           15.272           0.000
# L4.Eth_price_log_differenced_standardized              -0.779790         0.054636          -14.273           0.000
# L5.marketPriceEth_log_differenced_standardized         -0.576665         0.045326          -12.723           0.000
# L5.marketPriceUsd_log_differenced_standardized          0.686556         0.051043           13.450           0.000
# L5.Eth_price_log_differenced_standardized              -0.663272         0.058801          -11.280           0.000
# L6.marketPriceEth_log_differenced_standardized         -0.574010         0.048371          -11.867           0.000
# L6.marketPriceUsd_log_differenced_standardized          0.756036         0.055004           13.745           0.000
# L6.Eth_price_log_differenced_standardized              -0.608902         0.061049           -9.974           0.000
# L7.marketPriceEth_log_differenced_standardized         -0.546510         0.050964          -10.723           0.000
# L7.marketPriceUsd_log_differenced_standardized          0.648819         0.059326           10.937           0.000
# L7.Eth_price_log_differenced_standardized              -0.548615         0.062034           -8.844           0.000
# L8.marketPriceEth_log_differenced_standardized         -0.473542         0.052517           -9.017           0.000
# L8.marketPriceUsd_log_differenced_standardized          0.514921         0.061424            8.383           0.000
# L8.Eth_price_log_differenced_standardized              -0.479846         0.062541           -7.673           0.000
# L9.marketPriceEth_log_differenced_standardized         -0.453089         0.053502           -8.469           0.000
# L9.marketPriceUsd_log_differenced_standardized          0.552228         0.061677            8.954           0.000
# L9.Eth_price_log_differenced_standardized              -0.439450         0.060488           -7.265           0.000
# L10.marketPriceEth_log_differenced_standardized        -0.378590         0.052874           -7.160           0.000
# L10.marketPriceUsd_log_differenced_standardized         0.473273         0.061481            7.698           0.000
# L10.Eth_price_log_differenced_standardized             -0.412210         0.057305           -7.193           0.000
# L11.marketPriceEth_log_differenced_standardized        -0.410998         0.051646           -7.958           0.000
# L11.marketPriceUsd_log_differenced_standardized         0.436891         0.059637            7.326           0.000
# L11.Eth_price_log_differenced_standardized             -0.271967         0.054214           -5.017           0.000
# L12.marketPriceEth_log_differenced_standardized        -0.215436         0.049227           -4.376           0.000
# L12.marketPriceUsd_log_differenced_standardized         0.245325         0.056641            4.331           0.000
# L12.Eth_price_log_differenced_standardized             -0.265187         0.047788           -5.549           0.000
# L13.marketPriceEth_log_differenced_standardized        -0.236769         0.045159           -5.243           0.000
# L13.marketPriceUsd_log_differenced_standardized         0.275434         0.052098            5.287           0.000
# L13.Eth_price_log_differenced_standardized             -0.192460         0.039917           -4.822           0.000
# L14.marketPriceEth_log_differenced_standardized        -0.212993         0.039741           -5.359           0.000
# L14.marketPriceUsd_log_differenced_standardized         0.245304         0.045685            5.370           0.000
# L14.Eth_price_log_differenced_standardized             -0.046228         0.028237           -1.637           0.102
# L15.marketPriceEth_log_differenced_standardized        -0.109486         0.034139           -3.207           0.001
# L15.marketPriceUsd_log_differenced_standardized         0.128217         0.036120            3.550           0.000
# L15.Eth_price_log_differenced_standardized              0.015764         0.022093            0.714           0.476
# ==================================================================================================================
#
# Correlation matrix of residuals
#                                                marketPriceEth_log_differenced_standardized  marketPriceUsd_log_differenced_standardized  Eth_price_log_differenced_standardized
# marketPriceEth_log_differenced_standardized                                       1.000000                                     0.339080                               -0.141557
# marketPriceUsd_log_differenced_standardized                                       0.339080                                     1.000000                               -0.016395
# Eth_price_log_differenced_standardized                                           -0.141557                                    -0.016395                                1.000000

# %% [markdown]
# The Akaike information criterion(AIC) is used to evaluate how well a model fits the data. It penalizes for more independent variables to try to prevent over-fitting. AIC is calculated by the maximum log-likelihood of the model and the number of parameters (K) used to reach that likelihood. The AIC function is 2K – 2(log-likelihood).
#
# Lower AIC values indicate a better-fit model, and a model with a delta-AIC (the difference between the two AIC values being compared) of more than -2 is considered significantly better than the model it is being compared to.
#
# - https://www.scribbr.com/statistics/akaike-information-criterion/

# %%
results.plot()

# %% [markdown]
# ## Granger causality
#
# Granger causality is a hypothesis test for determining whether one time series is useful in forecasting another. We can say that a variable X, or variables, evolves over time Granger-causes another evolving variable Y if predictions of the value of Y based on its own past values and on the past values of X are better than predictions of Y based only on Y's own past values.
#
#
# In our analysis, we present the hypothesis that Eth is a driver of Rai market price. In statistical parlance, we have the following:
#
# * $H_O: \textrm{Eth price does not Granger cause Rai market price}$
# * $H_A: \textrm{Eth price does Granger cause Rai market price}$
#
# We will perform now perform the Granger Causality hypothesis test with an $\alpha = 0.05$ value using an F test to determine if the eth price has any casual component for predicting the Rai market price. If the p-value (the probability of obtaining test results at least as extreme as the results actually observed) of the test is less than or equal to $\alpha$ we will reject the null hypothesis and determine that Eth price is a driver of Rai market price.

# %%
results.test_causality(['marketPriceEth_log_differenced_standardized', 
                        'marketPriceUsd_log_differenced_standardized'],
                       'Eth_price_log_differenced_standardized', kind='f',signif=0.05).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Based on the Granger Causality test, we reject $H_O$ which means that Eth price does have a causal influence on Rai price.

# %%
results.test_causality('marketPriceEth_log_differenced_standardized',
                       'Eth_price_log_differenced_standardized', kind='f',signif=0.05).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Based on the Granger Causality test, we reject $H_O$ which means that Eth price does have a causal influence on Rai price in Eth.

# %%
results.test_causality('marketPriceUsd_log_differenced_standardized',
                       'Eth_price_log_differenced_standardized', kind='f',signif=0.05).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Based on the Granger Causality test, we reject $H_O$ which means that Eth price does have a causal influence on Rai price in Usd.

# %% [markdown]
# ## Impulse Response (Shock) Analysis
#
# Impulse response is used in econometrics and macroeconomic modeling to study how the system reacts to unit exogenous shocks. In signal processing, an impulse response is the reaction of a dynamic system in response to some external change. The Impulse response below is the estimated responses of a variable to a unit impulse.

# %%
# 50 periods
irf = results.irf(50)

# %%
irf.plot(impulse='Eth_price_log_differenced_standardized', #variable providing the unit impulse
         response='marketPriceUsd_log_differenced_standardized', # variable affected by the impulse
         plot_stderr = True, #Plot standard impulse response error bands
        repl=1000) #Number of replications for Monte Carlo and Sims-Zha standard errors

# %% [markdown]
# Standard errors are plotted by default at the 95% significance level.

# %% [markdown]
# ## Correlation Analysis

# %%
corr = P[['marketPriceEth_log_differenced_standardized',
          'marketPriceUsd_log_differenced_standardized',
          'Eth_price_log_differenced_standardized']].corr()
corr_cols = corr.columns
ax = sns.heatmap(corr, vmax=1.0, vmin=-1.0);
corr
# Out:
#                                              marketPriceEth_log_differenced_standardized  \
# marketPriceEth_log_differenced_standardized                                     1.000000
# marketPriceUsd_log_differenced_standardized                                     0.386231
# Eth_price_log_differenced_standardized                                         -0.174121
#
#                                              marketPriceUsd_log_differenced_standardized  \
# marketPriceEth_log_differenced_standardized                                     0.386231
# marketPriceUsd_log_differenced_standardized                                     1.000000
# Eth_price_log_differenced_standardized                                         -0.080395
#
#                                              Eth_price_log_differenced_standardized
# marketPriceEth_log_differenced_standardized                               -0.174121
# marketPriceUsd_log_differenced_standardized                               -0.080395
# Eth_price_log_differenced_standardized                                     1.000000

# %% [markdown]
# Using Pearson's correlation, we have a -0.174121.

# %% [markdown]
# ## Next steps
#
# * Sensativity checking casuality results with and without standardization.
# * **Validation of the relationship between the redemption rate to redemption price and error to redemption rate.**
# * ### New variables to add:
#     * Error
#     * Redemption rate
#     * Uniswap RAI balance relative to total RAI supply - RAI in Uniswap V2 (RAI/ETH) /  Outstanding RAI numerator.
#     * Rai supply/Rai cap (max debt ceiling) - From dashboard - Outstanding RAI. Numerator and Denominator are the same.
#     * ETH locked in collateral - Total ETH Locked
#     * Collateralization ratio - (Total ETH Locked * Value of Eth in USD) / (Total Rai outstanding * value of Rai in USD) - Denominator is the redemption price - Right equations
#     * Add lagged Eth value (1 hour) - get timestamps and do diffs and map to seconds. Plot histogram of seconds per interval. Representation of times.
# * Goal is to make some statements about how Rai is actually being dictated by Ethereum price moves.
#
# ## Conclusion
#
# Based on our VAR analysis, validating our hypothesis, Eth price does have an influence on the Rai price.
